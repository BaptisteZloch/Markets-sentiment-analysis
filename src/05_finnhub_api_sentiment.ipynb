# %%
import os
from dotenv import load_dotenv
import finnhub
from pprint import pprint

load_dotenv('../.env')
# Out:
# True

# %%
finnhub_client = finnhub.Client(api_key=os.environ.get("FINNHUB_API_KEY"))

# %%
pprint(finnhub_client.stock_social_sentiment('MSFT')['reddit'])
# Out:
# [{'atTime': '2023-02-26 20:00:00',
#   'mention': 1,
#   'negativeMention': 1,
#   'negativeScore': -0.9052511,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-26 19:00:00',
#   'mention': 1,
#   'negativeMention': 0,
#   'negativeScore': 0,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': 0},
#  {'atTime': '2023-02-26 18:00:00',
#   'mention': 2,
#   'negativeMention': 1,
#   'negativeScore': -0.94892734,
#   'positiveMention': 1,
#   'positiveScore': 0.9923294,
#   'score': 0.02235771245796165},
#  {'atTime': '2023-02-26 17:00:00',
#   'mention': 1,
#   'negativeMention': 0,
#   'negativeScore': 0,
#   'positiveMention': 1,
#   'positiveScore': 0.96542025,
#   'score': 1},
#  {'atTime': '2023-02-26 16:00:00',
#   'mention': 1,
#   'negativeMention': 1,
#   'negativeScore': -0.9844061,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-26 14:00:00',
#   'mention': 1,
#   'negativeMention': 1,
#   'negativeScore': -0.99893004,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-26 13:00:00',
#   'mention': 1,
#   'negativeMention': 1,
#   'negativeScore': -0.96786916,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-26 04:00:00',
#   'mention': 2,
#   'negativeMention': 1,
#   'negativeScore': -0.9999746,
#   'positiveMention': 1,
#   'positiveScore': 0.9868052,
#   'score': -0.006628515147979659},
#  {'atTime': '2023-02-26 01:00:00',
#   'mention': 2,
#   'negativeMention': 1,
#   'negativeScore': -0.99929285,
#   'positiveMention': 1,
#   'positiveScore': 0.7409915,
#   'score': -0.14842479621218221},
#  {'atTime': '2023-02-26 00:00:00',
#   'mention': 1,
#   'negativeMention': 1,
#   'negativeScore': -0.9996804,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 22:00:00',
#   'mention': 2,
#   'negativeMention': 1,
#   'negativeScore': -0.9999871,
#   'positiveMention': 1,
#   'positiveScore': 0.955725,
#   'score': -0.02263221667442768},
#  {'atTime': '2023-02-25 21:00:00',
#   'mention': 4,
#   'negativeMention': 3,
#   'negativeScore': -0.9941930666666666,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 20:00:00',
#   'mention': 1,
#   'negativeMention': 1,
#   'negativeScore': -0.9036056,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 19:00:00',
#   'mention': 1,
#   'negativeMention': 1,
#   'negativeScore': -0.9999372,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 18:00:00',
#   'mention': 3,
#   'negativeMention': 3,
#   'negativeScore': -0.9961376333333334,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 16:00:00',
#   'mention': 2,
#   'negativeMention': 2,
#   'negativeScore': -0.9777026,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 14:00:00',
#   'mention': 3,
#   'negativeMention': 3,
#   'negativeScore': -0.9944291000000001,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 13:00:00',
#   'mention': 4,
#   'negativeMention': 4,
#   'negativeScore': -0.963643425,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 11:00:00',
#   'mention': 1,
#   'negativeMention': 1,
#   'negativeScore': -0.9999404,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 06:00:00',
#   'mention': 7,
#   'negativeMention': 7,
#   'negativeScore': -0.9987792857142858,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 05:00:00',
#   'mention': 1,
#   'negativeMention': 0,
#   'negativeScore': 0,
#   'positiveMention': 1,
#   'positiveScore': 0.8321814,
#   'score': 1},
#  {'atTime': '2023-02-25 04:00:00',
#   'mention': 3,
#   'negativeMention': 3,
#   'negativeScore': -0.9888182333333333,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 03:00:00',
#   'mention': 6,
#   'negativeMention': 6,
#   'negativeScore': -0.950168,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 02:00:00',
#   'mention': 3,
#   'negativeMention': 3,
#   'negativeScore': -0.9626163333333334,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 01:00:00',
#   'mention': 4,
#   'negativeMention': 4,
#   'negativeScore': -0.9863639,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1},
#  {'atTime': '2023-02-25 00:00:00',
#   'mention': 9,
#   'negativeMention': 9,
#   'negativeScore': -0.980493888888889,
#   'positiveMention': 0,
#   'positiveScore': 0,
#   'score': -1}]

# %%
finnhub_client.stock_social_sentiment('AMZN')
# Out:
# {'reddit': [{'atTime': '2023-02-26 20:00:00',
#    'mention': 3,
#    'positiveScore': 0.90784496,
#    'negativeScore': -0.8492992,
#    'positiveMention': 1,
#    'negativeMention': 2,
#    'score': -0.3033840873488231},
#   {'atTime': '2023-02-26 19:00:00',
#    'mention': 3,
#    'positiveScore': 0.98139167,
#    'negativeScore': -0.9988109,
#    'positiveMention': 1,
#    'negativeMention': 2,
#    'score': -0.34112975326694306},
#   {'atTime': '2023-02-26 18:00:00',
#    'mention': 2,
#    'positiveScore': 0,
#    'negativeScore': -0.992757,
#    'positiveMention': 0,
#    'negativeMention': 1,
#    'score': -1},
#   {'atTime': '2023-02-26 16:00:00',
#    'mention': 1,
#    'positiveScore': 0,
#    'negativeScore': 0,
#    'positiveMention': 0,
#    'negativeMention': 0,
#    'score': 0},
#   {'atTime': '2023-02-26 14:00:00',
#    'mention': 3,
#    'positiveScore': 0,
#    'negativeScore': -0.9997032333333333,
#    'positiveMention': 0,
#    'negativeMention': 3,
#    'score': -1},
#   {'atTime': '2023-02-26 09:00:00',
#    'mention': 1,
#    'positiveScore': 0,
#    'negativeScore': -0.9999547,
#    'positiveMention': 0,
#    'negativeMention': 1,
#    'score': -1},
#   {'atTime': '2023-02-26 04:00:00',
#    'mention': 2,
#    'positiveScore': 0,
#    'negativeScore': -0.9999214,
#    'positiveMention': 0,
#    'negativeMention': 2,
#    'score': -1},
#   {'atTime': '2023-02-26 02:00:00',
#    'mention': 2,
#    'positiveScore': 0,
#    'negativeScore': -0.99951065,
#    'positiveMention': 0,
#    'negativeMention': 2,
#    'score': -1},
#   {'atTime': '2023-02-26 01:00:00',
#    'mention': 7,
#    'positiveScore': 0,
#    'negativeScore': -0.9819876142857142,
#    'positiveMention': 0,
#    'negativeMention': 7,
#    'score': -1},
#   {'atTime': '2023-02-26 00:00:00',
#    'mention': 2,
#    'positiveScore': 0,
#    'negativeScore': -0.97792065,
#    'positiveMention': 0,
#    'negativeMention': 2,
#    'score': -1},
#   {'atTime': '2023-02-25 23:00:00',
#    'mention': 1,
#    'positiveScore': 0.9925275,
#    'negativeScore': 0,
#    'positiveMention': 1,
#    'negativeMention': 0,
#    'score': 1},
#   {'atTime': '2023-02-25 22:00:00',
#    'mention': 1,
#    'positiveScore': 0,
#    'negativeScore': 0,
#    'positiveMention': 0,
#    'negativeMention': 0,
#    'score': 0},
#   {'atTime': '2023-02-25 21:00:00',
#    'mention': 2,
#    'positiveScore': 0,
#    'negativeScore': -0.8917618,
#    'positiveMention': 0,
#    'negativeMention': 2,
#    'score': -1},
#   {'atTime': '2023-02-25 20:00:00',
#    'mention': 4,
#    'positiveScore': 0.8678291,
#    'negativeScore': -0.99453845,
#    'positiveMention': 2,
#    'negativeMention': 2,
#    'score': -0.068036704140383},
#   {'atTime': '2023-02-25 19:00:00',
#    'mention': 4,
#    'positiveScore': 0.955439,
#    'negativeScore': -0.9890663,
#    'positiveMention': 2,
#    'negativeMention': 2,
#    'score': -0.017293498762898676},
#   {'atTime': '2023-02-25 18:00:00',
#    'mention': 3,
#    'positiveScore': 0,
#    'negativeScore': -0.9572816,
#    'positiveMention': 0,
#    'negativeMention': 3,
#    'score': -1},
#   {'atTime': '2023-02-25 17:00:00',
#    'mention': 19,
#    'positiveScore': 0.993919,
#    'negativeScore': -0.9812235,
#    'positiveMention': 2,
#    'negativeMention': 16,
#    'score': -0.7752257056910637},
#   {'atTime': '2023-02-25 16:00:00',
#    'mention': 3,
#    'positiveScore': 0,
#    'negativeScore': -0.9680298333333334,
#    'positiveMention': 0,
#    'negativeMention': 3,
#    'score': -1},
#   {'atTime': '2023-02-25 15:00:00',
#    'mention': 1,
#    'positiveScore': 0,
#    'negativeScore': -0.9999331,
#    'positiveMention': 0,
#    'negativeMention': 1,
#    'score': -1},
#   {'atTime': '2023-02-25 14:00:00',
#    'mention': 3,
#    'positiveScore': 0,
#    'negativeScore': -0.9990945,
#    'positiveMention': 0,
#    'negativeMention': 3,
#    'score': -1},
#   {'atTime': '2023-02-25 13:00:00',
#    'mention': 4,
#    'positiveScore': 0,
#    'negativeScore': -0.9990765,
#    'positiveMention': 0,
#    'negativeMention': 4,
#    'score': -1},
#   {'atTime': '2023-02-25 11:00:00',
#    'mention': 1,
#    'positiveScore': 0.98441297,
#    'negativeScore': 0,
#    'positiveMention': 1,
#    'negativeMention': 0,
#    'score': 1},
#   {'atTime': '2023-02-25 09:00:00',
#    'mention': 3,
#    'positiveScore': 0,
#    'negativeScore': -0.9271938,
#    'positiveMention': 0,
#    'negativeMention': 3,
#    'score': -1},
#   {'atTime': '2023-02-25 07:00:00',
#    'mention': 2,
#    'positiveScore': 0,
#    'negativeScore': -0.978695,
#    'positiveMention': 0,
#    'negativeMention': 2,
#    'score': -1},
#   {'atTime': '2023-02-25 06:00:00',
#    'mention': 7,
#    'positiveScore': 0.97073406,
#    'negativeScore': -0.9825407666666667,
#    'positiveMention': 1,
#    'negativeMention': 6,
#    'score': -0.7172335924504607},
#   {'atTime': '2023-02-25 05:00:00',
#    'mention': 10,
#    'positiveScore': 0.98986065,
#    'negativeScore': -0.972378125,
#    'positiveMention': 1,
#    'negativeMention': 8,
#    'score': -0.7742334226926543},
#   {'atTime': '2023-02-25 04:00:00',
#    'mention': 16,
#    'positiveScore': 0.8806812666666667,
#    'negativeScore': -0.9854424166666668,
#    'positiveMention': 3,
#    'negativeMention': 12,
#    'score': -0.6347578113944937},
#   {'atTime': '2023-02-25 03:00:00',
#    'mention': 8,
#    'positiveScore': 0.9301648,
#    'negativeScore': -0.9811756,
#    'positiveMention': 2,
#    'negativeMention': 5,
#    'score': -0.45011158096893156},
#   {'atTime': '2023-02-25 01:00:00',
#    'mention': 2,
#    'positiveScore': 0,
#    'negativeScore': -0.99956785,
#    'positiveMention': 0,
#    'negativeMention': 2,
#    'score': -1}],
#  'symbol': 'AMZN',
#  'twitter': [{'atTime': '2023-02-26 20:00:00',
#    'mention': 33,
#    'positiveScore': 0.9437386363636364,
#    'negativeScore': -0.93692375,
#    'positiveMention': 11,
#    'negativeMention': 16,
#    'score': -0.18168344079800078},
#   {'atTime': '2023-02-26 19:00:00',
#    'mention': 103,
#    'positiveScore': 0.9566808333333333,
#    'negativeScore': -0.9223669069767442,
#    'positiveMention': 48,
#    'negativeMention': 43,
#    'score': 0.07313301369695423},
#   {'atTime': '2023-02-26 18:00:00',
#    'mention': 72,
#    'positiveScore': 0.9371307407407408,
#    'negativeScore': -0.9286938965517242,
#    'positiveMention': 27,
#    'negativeMention': 29,
#    'score': -0.031197546196008993},
#   {'atTime': '2023-02-26 17:00:00',
#    'mention': 138,
#    'positiveScore': 0.9054478620689655,
#    'negativeScore': -0.9365560615384615,
#    'positiveMention': 58,
#    'negativeMention': 65,
#    'score': -0.07372794511646835},
#   {'atTime': '2023-02-26 16:00:00',
#    'mention': 89,
#    'positiveScore': 0.9496015,
#    'negativeScore': -0.9760476153846154,
#    'positiveMention': 40,
#    'negativeMention': 39,
#    'score': -0.001075569878662743},
#   {'atTime': '2023-02-26 15:00:00',
#    'mention': 44,
#    'positiveScore': 0.9652391904761904,
#    'negativeScore': -0.8802336666666667,
#    'positiveMention': 21,
#    'negativeMention': 18,
#    'score': 0.12255050495470911},
#   {'atTime': '2023-02-26 14:00:00',
#    'mention': 62,
#    'positiveScore': 0.9246154482758621,
#    'negativeScore': -0.9598941935483871,
#    'positiveMention': 29,
#    'negativeMention': 31,
#    'score': -0.05202125600011655},
#   {'atTime': '2023-02-26 13:00:00',
#    'mention': 74,
#    'positiveScore': 0.9288687837837838,
#    'negativeScore': -0.9360392258064516,
#    'positiveMention': 37,
#    'negativeMention': 31,
#    'score': 0.08441900330898165},
#   {'atTime': '2023-02-26 12:00:00',
#    'mention': 20,
#    'positiveScore': 0.9622700769230769,
#    'negativeScore': -0.9225423333333334,
#    'positiveMention': 13,
#    'negativeMention': 6,
#    'score': 0.3864975243512454},
#   {'atTime': '2023-02-26 11:00:00',
#    'mention': 74,
#    'positiveScore': 0.9731450689655172,
#    'negativeScore': -0.9557134722222221,
#    'positiveMention': 29,
#    'negativeMention': 36,
#    'score': -0.09875115629241188},
#   {'atTime': '2023-02-26 10:00:00',
#    'mention': 30,
#    'positiveScore': 0.9906055333333333,
#    'negativeScore': -0.9108617692307692,
#    'positiveMention': 15,
#    'negativeMention': 13,
#    'score': 0.11302800277120627},
#   {'atTime': '2023-02-26 09:00:00',
#    'mention': 21,
#    'positiveScore': 0.9304149428571428,
#    'negativeScore': -0.9515365,
#    'positiveMention': 7,
#    'negativeMention': 12,
#    'score': -0.2735731232975271},
#   {'atTime': '2023-02-26 08:00:00',
#    'mention': 8,
#    'positiveScore': 0,
#    'negativeScore': -0.8569656166666667,
#    'positiveMention': 0,
#    'negativeMention': 6,
#    'score': -1},
#   {'atTime': '2023-02-26 07:00:00',
#    'mention': 24,
#    'positiveScore': 0.9389176666666667,
#    'negativeScore': -0.9589343333333333,
#    'positiveMention': 12,
#    'negativeMention': 9,
#    'score': 0.13250978606724956},
#   {'atTime': '2023-02-26 06:00:00',
#    'mention': 11,
#    'positiveScore': 0.9232617,
#    'negativeScore': -0.8437243,
#    'positiveMention': 2,
#    'negativeMention': 9,
#    'score': -0.6087891599551235},
#   {'atTime': '2023-02-26 05:00:00',
#    'mention': 14,
#    'positiveScore': 0.9661895555555555,
#    'negativeScore': -0.999993,
#    'positiveMention': 9,
#    'negativeMention': 3,
#    'score': 0.4869938785116049},
#   {'atTime': '2023-02-26 04:00:00',
#    'mention': 29,
#    'positiveScore': 0.9394655833333333,
#    'negativeScore': -0.9353847333333333,
#    'positiveMention': 12,
#    'negativeMention': 15,
#    'score': -0.10896083591609004},
#   {'atTime': '2023-02-26 03:00:00',
#    'mention': 42,
#    'positiveScore': 0.9219025294117646,
#    'negativeScore': -0.934086,
#    'positiveMention': 17,
#    'negativeMention': 22,
#    'score': -0.13465621323477142},
#   {'atTime': '2023-02-26 02:00:00',
#    'mention': 25,
#    'positiveScore': 0.9823199,
#    'negativeScore': -0.9278314666666667,
#    'positiveMention': 10,
#    'negativeMention': 15,
#    'score': -0.17245818367981258},
#   {'atTime': '2023-02-26 01:00:00',
#    'mention': 42,
#    'positiveScore': 0.9467874166666667,
#    'negativeScore': -0.9728405333333333,
#    'positiveMention': 24,
#    'negativeMention': 15,
#    'score': 0.21787966643142936},
#   {'atTime': '2023-02-26 00:00:00',
#    'mention': 32,
#    'positiveScore': 0.9508558636363635,
#    'negativeScore': -0.9480571428571428,
#    'positiveMention': 11,
#    'negativeMention': 21,
#    'score': -0.3111694641189508},
#   {'atTime': '2023-02-25 23:00:00',
#    'mention': 25,
#    'positiveScore': 0.9103758571428572,
#    'negativeScore': -0.9139927058823529,
#    'positiveMention': 7,
#    'negativeMention': 17,
#    'score': -0.4183036476517864},
#   {'atTime': '2023-02-25 22:00:00',
#    'mention': 56,
#    'positiveScore': 0.8718800625,
#    'negativeScore': -0.9648024166666667,
#    'positiveMention': 16,
#    'negativeMention': 36,
#    'score': -0.42690096462483546},
#   {'atTime': '2023-02-25 21:00:00',
#    'mention': 23,
#    'positiveScore': 0.804045,
#    'negativeScore': -0.8509243076923076,
#    'positiveMention': 6,
#    'negativeMention': 13,
#    'score': -0.39264973575321505},
#   {'atTime': '2023-02-25 20:00:00',
#    'mention': 26,
#    'positiveScore': 0.9410406923076924,
#    'negativeScore': -0.9125063333333333,
#    'positiveMention': 13,
#    'negativeMention': 12,
#    'score': 0.05536037212504274},
#   {'atTime': '2023-02-25 19:00:00',
#    'mention': 69,
#    'positiveScore': 0.9281745454545455,
#    'negativeScore': -0.9283267857142857,
#    'positiveMention': 33,
#    'negativeMention': 28,
#    'score': 0.08188575966865709},
#   {'atTime': '2023-02-25 18:00:00',
#    'mention': 42,
#    'positiveScore': 0.9304100428571429,
#    'negativeScore': -0.9331622413793104,
#    'positiveMention': 7,
#    'negativeMention': 29,
#    'score': -0.6120355809832091},
#   {'atTime': '2023-02-25 17:00:00',
#    'mention': 9,
#    'positiveScore': 0.99887395,
#    'negativeScore': -0.8757839,
#    'positiveMention': 2,
#    'negativeMention': 2,
#    'score': 0.0656600083049822},
#   {'atTime': '2023-02-25 16:00:00',
#    'mention': 54,
#    'positiveScore': 0.9388016363636363,
#    'negativeScore': -0.920810325,
#    'positiveMention': 11,
#    'negativeMention': 40,
#    'score': -0.5620446821959416},
#   {'atTime': '2023-02-25 15:00:00',
#    'mention': 8,
#    'positiveScore': 0.925485,
#    'negativeScore': -0.897221375,
#    'positiveMention': 4,
#    'negativeMention': 4,
#    'score': 0.015506405961848909},
#   {'atTime': '2023-02-25 14:00:00',
#    'mention': 52,
#    'positiveScore': 0.9425150476190476,
#    'negativeScore': -0.9156336666666666,
#    'positiveMention': 21,
#    'negativeMention': 24,
#    'score': -0.05225030516167105},
#   {'atTime': '2023-02-25 13:00:00',
#    'mention': 57,
#    'positiveScore': 0.9604576896551724,
#    'negativeScore': -0.94779,
#    'positiveMention': 29,
#    'negativeMention': 24,
#    'score': 0.10091481199305939},
#   {'atTime': '2023-02-25 12:00:00',
#    'mention': 36,
#    'positiveScore': 0.9314462142857144,
#    'negativeScore': -0.938842705882353,
#    'positiveMention': 14,
#    'negativeMention': 17,
#    'score': -0.10069038980712551},
#   {'atTime': '2023-02-25 11:00:00',
#    'mention': 3,
#    'positiveScore': 0.99718505,
#    'negativeScore': -0.98955977,
#    'positiveMention': 2,
#    'negativeMention': 1,
#    'score': 0.33674059839750864},
#   {'atTime': '2023-02-25 10:00:00',
#    'mention': 9,
#    'positiveScore': 0.98732065,
#    'negativeScore': -0.9873903333333334,
#    'positiveMention': 2,
#    'negativeMention': 6,
#    'score': -0.500026465431317},
#   {'atTime': '2023-02-25 09:00:00',
#    'mention': 14,
#    'positiveScore': 0.8458225199999999,
#    'negativeScore': -0.8521814375,
#    'positiveMention': 5,
#    'negativeMention': 8,
#    'score': -0.23431167162647434},
#   {'atTime': '2023-02-25 08:00:00',
#    'mention': 14,
#    'positiveScore': 0.96994115,
#    'negativeScore': -0.99914,
#    'positiveMention': 2,
#    'negativeMention': 4,
#    'score': -0.3464495393141444},
#   {'atTime': '2023-02-25 07:00:00',
#    'mention': 25,
#    'positiveScore': 0.9182308000000001,
#    'negativeScore': -0.8916950714285715,
#    'positiveMention': 5,
#    'negativeMention': 14,
#    'score': -0.4622330984952461},
#   {'atTime': '2023-02-25 06:00:00',
#    'mention': 22,
#    'positiveScore': 0.9031171666666666,
#    'negativeScore': -0.9340834285714286,
#    'positiveMention': 3,
#    'negativeMention': 14,
#    'score': -0.656751255398633},
#   {'atTime': '2023-02-25 05:00:00',
#    'mention': 35,
#    'positiveScore': 0.9421765625,
#    'negativeScore': -0.95571325,
#    'positiveMention': 16,
#    'negativeMention': 16,
#    'score': -0.007132493894452538},
#   {'atTime': '2023-02-25 04:00:00',
#    'mention': 16,
#    'positiveScore': 0.87628465,
#    'negativeScore': -0.9181330000000001,
#    'positiveMention': 4,
#    'negativeMention': 10,
#    'score': -0.4474209158567578},
#   {'atTime': '2023-02-25 03:00:00',
#    'mention': 25,
#    'positiveScore': 0.8779685,
#    'negativeScore': -0.9110415384615386,
#    'positiveMention': 6,
#    'negativeMention': 13,
#    'score': -0.3842904630966895},
#   {'atTime': '2023-02-25 02:00:00',
#    'mention': 54,
#    'positiveScore': 0.9200117999999999,
#    'negativeScore': -0.9141460625,
#    'positiveMention': 20,
#    'negativeMention': 32,
#    'score': -0.22773925034168951},
#   {'atTime': '2023-02-25 01:00:00',
#    'mention': 3,
#    'positiveScore': 0.9833406666666668,
#    'negativeScore': 0,
#    'positiveMention': 3,
#    'negativeMention': 0,
#    'score': 1},
#   {'atTime': '2023-02-25 00:00:00',
#    'mention': 66,
#    'positiveScore': 0.924691081081081,
#    'negativeScore': -0.8760010416666667,
#    'positiveMention': 37,
#    'negativeMention': 24,
#    'score': 0.23877840807515235}]}
